# %%
import pandas as pd

# %%
df=pd.read_csv('../data/기아_고객1600명_더미데이터.csv')

# %%
df
# Out:
#                     이름        생년월일  연령 성별                  휴대폰번호  \
# 0        Emily Johnson  1987-05-25  38  남        +1-983-243-5951
# 1        Jessica Smith  1979-11-24  46  여       001-718-884-2716
# 2         Robert White  1984-08-25  41  남          (532)836-9308
# 3           John Smith  1971-08-07  54  여           640.695.8051
# 4         Emily Thomas  1991-12-26  34  여  +1-023-521-7921x18289
# ...                ...         ...  .. ..                    ...
# 1595  Camila Hernandez  1985-02-03  40  남       652-029-6179x273
# 1596    Valeria Vargas  1997-06-06  28  남   1-448-627-0126x80613
# 1597    Valeria Vargas  1974-06-26  51  여    1-989-857-5629x2721
# 1598      Juan Morales  1969-05-16  56  남          (000)338-9320
# 1599     Miguel Rivera  1971-12-30  54  여         1-112-251-0558
#
#                                  이메일  \
# 0     jeremyberger@newton-watson.com
# 1               robert55@hotmail.com
# 2          garciaelizabeth@burns.net
# ...

# %%
df['지역'].unique()
# Out:
# array(['미국', '서유럽', '아시아', '중동아프리카', '중남미', '캐나다', '동유럽', '멕시코'],
#       dtype=object)
